# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from xgboost import XGBClassifier
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# %%
train = pd.read_csv('Train.csv')
test = pd.read_csv('Test.csv')

# %%
train.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          NaN     956940.0          NaN     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56000 entries, 0 to 55999
# Data columns (total 52 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Applicant_ID    56000 non-null  object
#  1   form_field1     53471 non-null  float64
#  2   form_field2     52156 non-null  float64
#  3   form_field3     55645 non-null  float64
#  4   form_field4     55645 non-null  float64
#  5   form_field5     55645 non-null  float64
#  6   form_field6     42640 non-null  float64
#  7   form_field7     50837 non-null  float64
#  8   form_field8     42640 non-null  float64
#  9   form_field9     47992 non-null  float64
#  10  form_field10    55645 non-null  float64
#  11  form_field11    24579 non-null  float64
#  12  form_field12    46105 non-null  float64
#  13  form_field13    50111 non-null  float64
#  14  form_field14    56000 non-null  int64
#  15  form_field15    33525 non-null  float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 51 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  24000 non-null  object
#  1   form_field1   22890 non-null  float64
#  2   form_field2   22291 non-null  float64
#  3   form_field3   23854 non-null  float64
#  4   form_field4   23854 non-null  float64
#  5   form_field5   23854 non-null  float64
#  6   form_field6   18396 non-null  float64
#  7   form_field7   21769 non-null  float64
#  8   form_field8   18396 non-null  float64
#  9   form_field9   20600 non-null  float64
#  10  form_field10  23853 non-null  float64
#  11  form_field11  10602 non-null  float64
#  12  form_field12  19817 non-null  float64
#  13  form_field13  21537 non-null  float64
#  14  form_field14  24000 non-null  int64
#  15  form_field15  14408 non-null  float64
#  16  form_field16  18526 non-null  float64
# ...

# %%
train['default_status']=train['default_status'].map({'no':0,'yes':1})

# %%
train.head()
# Out:
#     Applicant_ID  form_field1  form_field2  form_field3  form_field4  \
# 0  Apcnt_1000000       3436.0      0.28505       1.6560          0.0
# 1  Apcnt_1000004       3456.0      0.67400       0.2342          0.0
# 2  Apcnt_1000008       3276.0      0.53845       3.1510          0.0
# 3  Apcnt_1000012       3372.0      0.17005       0.5050          0.0
# 4  Apcnt_1000016       3370.0      0.77270       1.1010          0.0
#
#    form_field5  form_field6  form_field7  form_field8  form_field9  ...  \
# 0        0.000          0.0   10689720.0     252072.0    4272776.0  ...
# 1        0.000          0.0     898979.0     497531.0    9073814.0  ...
# 2        6.282          NaN     956940.0          NaN     192944.0  ...
# 3        0.000     192166.0    3044703.0     385499.0    3986472.0  ...
# 4        0.000       1556.0     214728.0     214728.0    1284089.0  ...
#
#    form_field42  form_field43  form_field44  form_field45  form_field46  \
# ...

# %%
test['form_field47'].value_counts()
# Out:
# charge     15467
# lending     8533
# Name: form_field47, dtype: int64

# %%
train['form_field47']=train['form_field47'].map({'charge':0,'lending':1})

# %%
train.form_field1  = train['form_field1'].fillna(-1)
test.form_field1  = test['form_field1'].fillna(-1)

train.form_field2  = train['form_field2'].fillna(-1)
test.form_field2  = test['form_field2'].fillna(-1)

train.form_field3  = train['form_field3'].fillna(-1)
test.form_field3  = test['form_field3'].fillna(-1)


train.form_field4  = train['form_field4'].fillna(-1)
test.form_field4  = test['form_field4'].fillna(-1)

train.form_field5  = train['form_field5'].fillna(-1)
test.form_field5  = test['form_field5'].fillna(-1)

train.form_field6  = train['form_field6'].fillna(-1)
test.form_field6  = test['form_field6'].fillna(-1)

train.form_field7  = train['form_field7'].fillna(-1)
test.form_field7  = test['form_field7'].fillna(-1)

train.form_field8  = train['form_field8'].fillna(-1)
test.form_field8  = test['form_field8'].fillna(-1)

train.form_field9  = train['form_field9'].fillna(-1)
test.form_field9 = test['form_field9'].fillna(-1)

train.form_field10  = train['form_field10'].fillna(-1)
test.form_field10  = test['form_field10'].fillna(-1)

train.form_field11  = train['form_field11'].fillna(-1)
test.form_field11  = test['form_field11'].fillna(-1)

train.form_field12  = train['form_field12'].fillna(-1)
test.form_field12  = test['form_field12'].fillna(-1)

train.form_field13  = train['form_field13'].fillna(-1)
test.form_field13  = test['form_field13'].fillna(-1)


train.form_field15  = train['form_field15'].fillna(-1)
test.form_field15  = test['form_field15'].fillna(-1)

train.form_field16  = train['form_field16'].fillna(-1)
test.form_field16  = test['form_field16'].fillna(-1)


train.form_field17  = train['form_field17'].fillna(-1)
test.form_field17  = test['form_field17'].fillna(-1)

train.form_field18  = train['form_field18'].fillna(-1)
test.form_field18  = test['form_field18'].fillna(-1)



train.form_field20  = train['form_field20'].fillna(-1)
test.form_field20  = test['form_field20'].fillna(-1)

train.form_field21  = train['form_field21'].fillna(-1)
test.form_field21  = test['form_field21'].fillna(-1)

train.form_field22  = train['form_field22'].fillna(-1)
test.form_field22  = test['form_field22'].fillna(-1)

train.form_field23  = train['form_field23'].fillna(-1)
test.form_field23  = test['form_field23'].fillna(-1)

train.form_field24  = train['form_field24'].fillna(-1)
test.form_field24  = test['form_field24'].fillna(-1)

train.form_field25  = train['form_field25'].fillna(-1)
test.form_field25  = test['form_field25'].fillna(-1)

train.form_field26  = train['form_field26'].fillna(-1)
test.form_field26 = test['form_field26'].fillna(-1)

train.form_field27  = train['form_field27'].fillna(-1)
test.form_field27  = test['form_field27'].fillna(-1)

train.form_field28  = train['form_field28'].fillna(-1)
test.form_field28 = test['form_field28'].fillna(-1)

train.form_field29 = train['form_field29'].fillna(-1)
test.form_field29 = test['form_field29'].fillna(-1)

train.form_field30  = train['form_field30'].fillna(-1)
test.form_field30  = test['form_field30'].fillna(-1)

train.form_field31  = train['form_field31'].fillna(-1)
test.form_field31  = test['form_field31'].fillna(-1)

train.form_field32 = train['form_field32'].fillna(-1)
test.form_field32  = test['form_field32'].fillna(-1)

train.form_field33  = train['form_field33'].fillna(-1)
test.form_field33  = test['form_field33'].fillna(-1)

train.form_field34  = train['form_field34'].fillna(-1)
test.form_field34  = test['form_field34'].fillna(-1)

train.form_field35  = train['form_field35'].fillna(-1)
test.form_field35  = test['form_field35'].fillna(-1)

train.form_field36  = train['form_field36'].fillna(-1)
test.form_field36  = test['form_field36'].fillna(-1)

train.form_field37  = train['form_field37'].fillna(-1)
test.form_field37  = test['form_field37'].fillna(-1)


train.form_field38  = train['form_field38'].fillna(-1)
test.form_field38 = test['form_field38'].fillna(-1)

train.form_field39  = train['form_field39'].fillna(-1)
test.form_field39 = test['form_field39'].fillna(-1)

train.form_field40  = train['form_field40'].fillna(-1)
test.form_field40  = test['form_field40'].fillna(-1)


train.form_field41  = train['form_field41'].fillna(-1)
test.form_field41  = test['form_field41'].fillna(-1)


train.form_field42  = train['form_field42'].fillna(-1)
test.form_field42  = test['form_field42'].fillna(-1)

train.form_field43  = train['form_field43'].fillna(-1)
test.form_field43  = test['form_field43'].fillna(-1)

train.form_field44  = train['form_field44'].fillna(-1)
test.form_field44  = test['form_field44'].fillna(-1)

train.form_field45  = train['form_field45'].fillna(-1)
test.form_field45  = test['form_field45'].fillna(-1)

train.form_field46 = train['form_field46'].fillna(-1)
test.form_field46  = test['form_field46'].fillna(-1)

train.form_field47 = train['form_field47'].fillna(-1)
test.form_field47  = test['form_field47'].fillna(-1)


train.form_field48  = train['form_field48'].fillna(-1)
test.form_field48  = test['form_field48'].fillna(-1)

train.form_field49  = train['form_field49'].fillna(-1)
test.form_field49  = test['form_field49'].fillna(-1)

train.form_field50 = train['form_field50'].fillna(-1)
test.form_field50  = test['form_field50'].fillna(-1)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24000 entries, 0 to 23999
# Data columns (total 51 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Applicant_ID  24000 non-null  object
#  1   form_field1   24000 non-null  float64
#  2   form_field2   24000 non-null  float64
#  3   form_field3   24000 non-null  float64
#  4   form_field4   24000 non-null  float64
#  5   form_field5   24000 non-null  float64
#  6   form_field6   24000 non-null  float64
#  7   form_field7   24000 non-null  float64
#  8   form_field8   24000 non-null  float64
#  9   form_field9   24000 non-null  float64
#  10  form_field10  24000 non-null  float64
#  11  form_field11  24000 non-null  float64
#  12  form_field12  24000 non-null  float64
#  13  form_field13  24000 non-null  float64
#  14  form_field14  24000 non-null  int64
#  15  form_field15  24000 non-null  float64
#  16  form_field16  24000 non-null  float64
# ...

# %%
test = test.drop(['Applicant_ID','form_field47'],axis=1)
train = train.drop(['Applicant_ID','form_field47'],axis=1)

# %%
X=train.drop(['default_status'], axis=1)
y = train.default_status
test 
X.shape
# Out:
# (56000, 49)

# %%
y.shape
# Out:
# (56000,)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import StratifiedKFold
from catboost import CatBoostClassifier

# %%
error_list =[]
test_accuracy=[]

fold = StratifiedKFold(n_splits=10,shuffle=True, random_state=42)

fold.get_n_splits(X,y)

for train_index,test_index in fold.split(X,y):
    X_train,X_test = X.iloc[train_index],X.iloc[test_index]
    y_train,y_test= y.iloc[train_index], y.iloc[test_index]
    
    ml= CatBoostClassifier(n_estimators=1000,eval_metric='AUC',max_depth=4,learning_rate=0.1,od_wait=50,reg_lambda=3,bootstrap_type='Bayesian',use_best_model=True)
    
    ml.fit(X_train,y_train,eval_set= [(X_train,y_train),(X_test,y_test)],early_stopping_rounds=100,verbose=100)
    
    preds=ml.predict_proba(X_test)[:,1]
    print ('err:',roc_auc_score(y_test,preds))
    
    error_list.append(roc_auc_score(y_test,preds))
    
    p1=ml.predict_proba(test)[:,1]
    test_accuracy.append(p1)
# Out:
# 0:	test: 0.7706447	test1: 0.7845105	best: 0.7845105 (0)	total: 71.3ms	remaining: 1m 11s
# 100:	test: 0.8278467	test1: 0.8397033	best: 0.8398389 (96)	total: 7.47s	remaining: 1m 6s
# 200:	test: 0.8349525	test1: 0.8420680	best: 0.8421407 (187)	total: 14.7s	remaining: 58.2s
# 300:	test: 0.8405972	test1: 0.8432048	best: 0.8432048 (300)	total: 23.4s	remaining: 54.3s
# 400:	test: 0.8451783	test1: 0.8433123	best: 0.8435004 (373)	total: 32s	remaining: 47.8s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.8435004456
# bestIteration = 373
#
# Shrink model to first 374 iterations.
# err: 0.8435004455878353
# 0:	test: 0.7738405	test1: 0.7702321	best: 0.7702321 (0)	total: 91.2ms	remaining: 1m 31s
# 100:	test: 0.8291113	test1: 0.8227523	best: 0.8227523 (100)	total: 7.76s	remaining: 1m 9s
# 200:	test: 0.8367451	test1: 0.8257737	best: 0.8258020 (191)	total: 14.8s	remaining: 59s
# 300:	test: 0.8420274	test1: 0.8268856	best: 0.8270474 (287)	total: 22s	remaining: 51.2s
# ...

# %%
np.mean(error_list)
# Out:
# 0.8289788603616539

# %%
test= pd.read_csv('Test.csv')
SUB5= pd.DataFrame({'Applicant_ID':test['Applicant_ID'] , 'default_status': np.mean(test_accuracy,0)})

# %%
SUB5.head()
# Out:
#     Applicant_ID  default_status
# 0  Apcnt_1000032        0.285255
# 1  Apcnt_1000048        0.471665
# 2  Apcnt_1000052        0.338343
# 3  Apcnt_1000076        0.706576
# 4  Apcnt_1000080        0.317166

# %%
SUB5.to_csv('submission5.csv',index=False)
